# %% [markdown]
#  # **Oriana Felszer**: 345143655
#  # **Aron Bensimhon**: 342762689

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://www.ad.co.il/car?sp261=69868"
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36'
}
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')
soup.find_all('div', class_='card-block')
# Out:
# [<div class="card-block" data-id="16186570" data-images="10" onclick="clickad(16186570)">
#  <div class="card overflow-hidden">
#  <picture class="card-img-top picbg">
#  <source media="(max-width: 767px)" srcset="//img3.ad.co.il/CarImages/3935038-300_0.jpg"/>
#  <source srcset="//img3.ad.co.il/CarImages/3935038-400_0.jpg"/>
#  <img alt="" class="img-fluid" decoding="async" loading="lazy" onload="this.style.opacity = 1" src="//img3.ad.co.il/CarImages/3935038-400_0.jpg"/>
#  </picture>
#  <div class="card-body p-md-3">
#  <a href="/ad/16186570"><h2 class="card-title mb-0 mb-sm-1">טסלה מודל 3</h2></a>
#  <div class="card-text my-1 mb-1 mt-0 d-flex justify-content-between">
#  <div>
#                          2021
#                      </div>
#  <div>
#                          5%<i class="fas fa-long-arrow-alt-down ps-1 pe-2"></i>
#  <span class="text-decoration-line-through text-400"></span>
#  </div>
#  </div>
#  <div class="d-flex justify-content-between">
#  <div class="d-inline-flex">
#  <div class="me-2 flex-fill card-icon-wrapper">
#  <i class="fa fa-tachometer-alt"></i>
#  <span class="ms-1">48K<span class="d-none d-md-inline-block"> ק"מ</span></span>
#  </div>
#  <div class="flex-fill card-icon-wrapper">
#  <i class="fa fa-hand-paper"></i>
#  <span class="ms-1">1<span class="d-none d-md-inline-block"> יד</span></span>
#  </div>
#  </div>
#  <div class="price ms-1">190,000 ₪</div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card-block" data-id="16067490" data-images="10" onclick="clickad(16067490)">
#  <div class="card overflow-hidden">
#  <picture class="card-img-top picbg">
#  <source media="(max-width: 767px)" srcset="//img2.ad.co.il/CarImages/3898725-300_0.jpg"/>
#  <source srcset="//img2.ad.co.il/CarImages/3898725-400_0.jpg"/>
#  <img alt="" class="img-fluid" decoding="async" loading="lazy" onload="this.style.opacity = 1" src="//img2.ad.co.il/CarImages/3898725-400_0.jpg"/>
#  </picture>
#  <div class="card-body p-md-3">
#  <a href="/ad/16067490"><h2 class="card-title mb-0 mb-sm-1">טסלה מודל 3</h2></a>
#  <p class="card-text my-1 mb-1 mt-0">
#                      2022
#                  </p>
#  <div class="d-flex justify-content-between">
#  <div class="d-inline-flex">
#  <div class="me-2 flex-fill card-icon-wrapper">
#  <i class="fa fa-tachometer-alt"></i>
#  <span class="ms-1">33K<span class="d-none d-md-inline-block"> ק"מ</span></span>
#  </div>
#  <div class="flex-fill card-icon-wrapper">
#  <i class="fa fa-hand-paper"></i>
#  <span class="ms-1">1<span class="d-none d-md-inline-block"> יד</span></span>
#  </div>
#  </div>
#  <div class="price ms-1">145,000 ₪</div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card-block" data-id="16146497" data-images="5" onclick="clickad(16146497)">
#  <div class="card overflow-hidden">
#  <picture class="card-img-top picbg">
#  <source media="(max-width: 767px)" srcset="//img3.ad.co.il/CarImages/3921334-300_0.jpg"/>
#  <source srcset="//img3.ad.co.il/CarImages/3921334-400_0.jpg"/>
#  <img alt="" class="img-fluid" decoding="async" loading="lazy" onload="this.style.opacity = 1" src="//img3.ad.co.il/CarImages/3921334-400_0.jpg"/>
#  </picture>
#  <div class="card-body p-md-3">
#  <a href="/ad/16146497"><h2 class="card-title mb-0 mb-sm-1">טסלה מודל S</h2></a>
#  <p class="card-text my-1 mb-1 mt-0">
#                      2018
#                  </p>
#  <div class="d-flex justify-content-between">
#  <div class="d-inline-flex">
#  <div class="flex-fill card-icon-wrapper">
#  <i class="fa fa-hand-paper"></i>
#  <span class="ms-1">2<span class="d-none d-md-inline-block"> יד</span></span>
#  </div>
#  </div>
#  <div class="price ms-1">13,000 ₪</div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card-block" data-id="15904463" data-images="4" onclick="clickad(15904463)">
#  <div class="card overflow-hidden">
#  <picture class="card-img-top picbg">
#  <source media="(max-width: 767px)" srcset="//img3.ad.co.il/CarImages/3843618-300_0.jpg"/>
#  <source srcset="//img3.ad.co.il/CarImages/3843618-400_0.jpg"/>
#  <img alt="" class="img-fluid" decoding="async" loading="lazy" onload="this.style.opacity = 1" src="//img3.ad.co.il/CarImages/3843618-400_0.jpg"/>
#  </picture>
#  <div class="card-body p-md-3">
#  <a href="/ad/15904463"><h2 class="card-title mb-0 mb-sm-1">טסלה מודל 3</h2></a>
#  <p class="card-text my-1 mb-1 mt-0">
#                      2021
#                  </p>
#  <div class="d-flex justify-content-between">
#  <div class="d-inline-flex">
#  <div class="me-2 flex-fill card-icon-wrapper">
#  <i class="fa fa-tachometer-alt"></i>
#  <span class="ms-1">79K<span class="d-none d-md-inline-block"> ק"מ</span></span>
#  </div>
#  <div class="flex-fill card-icon-wrapper">
#  <i class="fa fa-hand-paper"></i>
#  <span class="ms-1">2<span class="d-none d-md-inline-block"> יד</span></span>
#  </div>
#  </div>
#  <div class="price ms-1">179,000 ₪</div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card-block" data-id="15884168" data-images="1" onclick="clickad(15884168)">
#  <div class="card overflow-hidden">
#  <picture class="card-img-top picbg">
#  <source media="(max-width: 767px)" srcset="//img4.ad.co.il/CarImages/3841471-300_0.jpg"/>
#  <source srcset="//img4.ad.co.il/CarImages/3841471-400_0.jpg"/>
#  <img alt="" class="img-fluid" decoding="async" loading="lazy" onload="this.style.opacity = 1" src="//img4.ad.co.il/CarImages/3841471-400_0.jpg"/>
#  </picture>
#  <div class="card-body p-md-3">
#  <a href="/ad/15884168"><h2 class="card-title mb-0 mb-sm-1">טסלה מודל 3</h2></a>
#  <p class="card-text my-1 mb-1 mt-0">
#                      2023
#                  </p>
#  <div class="d-flex justify-content-between">
#  <div class="d-inline-flex">
#  <div class="me-2 flex-fill card-icon-wrapper">
#  <i class="fa fa-tachometer-alt"></i>
#  <span class="ms-1">1K<span class="d-none d-md-inline-block"> ק"מ</span></span>
#  </div>
#  <div class="flex-fill card-icon-wrapper">
#  <i class="fa fa-hand-paper"></i>
#  <span class="ms-1">2<span class="d-none d-md-inline-block"> יד</span></span>
#  </div>
#  </div>
#  <div class="price ms-1">225,000 ₪</div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card-block" data-id="15789782" data-images="8" onclick="clickad(15789782)">
#  <div class="card overflow-hidden">
#  <picture class="card-img-top picbg">
#  <source media="(max-width: 767px)" srcset="//img3.ad.co.il/CarImages/3822998-300_0.jpg"/>
#  <source srcset="//img3.ad.co.il/CarImages/3822998-400_0.jpg"/>
#  <img alt="" class="img-fluid" decoding="async" loading="lazy" onload="this.style.opacity = 1" src="//img3.ad.co.il/CarImages/3822998-400_0.jpg"/>
#  </picture>
#  <div class="card-body p-md-3">
#  <a href="/ad/15789782"><h2 class="card-title mb-0 mb-sm-1">טסלה מודל X</h2></a>
#  <p class="card-text my-1 mb-1 mt-0">
#                      2023
#                  </p>
#  <div class="d-flex justify-content-between">
#  <div class="d-inline-flex">
#  <div class="flex-fill card-icon-wrapper">
#  <i class="fa fa-hand-paper"></i>
#  <span class="ms-1">1<span class="d-none d-md-inline-block"> יד</span></span>
#  </div>
#  </div>
#  <div class="price ms-1">280,000 ₪</div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card-block" data-id="15443695" data-images="2" onclick="clickad(15443695)">
#  <div class="card overflow-hidden">
#  <picture class="card-img-top picbg">
#  <source media="(max-width: 767px)" srcset="//img3.ad.co.il/CarImages/3694694-300_0.jpg"/>
#  <source srcset="//img3.ad.co.il/CarImages/3694694-400_0.jpg"/>
#  <img alt="" class="img-fluid" decoding="async" loading="lazy" onload="this.style.opacity = 1" src="//img3.ad.co.il/CarImages/3694694-400_0.jpg"/>
#  </picture>
#  <div class="card-body p-md-3">
#  <a href="/ad/15443695"><h2 class="card-title mb-0 mb-sm-1">טסלה מודל 3</h2></a>
#  <div class="card-text my-1 mb-1 mt-0 d-flex justify-content-between">
#  <div>
#                          2021
#                      </div>
#  <div>
#                          8%<i class="fas fa-long-arrow-alt-down ps-1 pe-2"></i>
#  <span class="text-decoration-line-through text-400"></span>
#  </div>
#  </div>
#  <div class="d-flex justify-content-between">
#  <div class="d-inline-flex">
#  <div class="me-2 flex-fill card-icon-wrapper">
#  <i class="fa fa-tachometer-alt"></i>
#  <span class="ms-1">59K<span class="d-none d-md-inline-block"> ק"מ</span></span>
#  </div>
#  <div class="flex-fill card-icon-wrapper">
#  <i class="fa fa-hand-paper"></i>
#  <span class="ms-1">1<span class="d-none d-md-inline-block"> יד</span></span>
#  </div>
#  </div>
#  <div class="price ms-1">180,000 ₪</div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card-block" data-id="15153584" data-images="3" onclick="clickad(15153584)">
#  <div class="card overflow-hidden">
#  <picture class="card-img-top picbg">
#  <source media="(max-width: 767px)" srcset="//img4.ad.co.il/CarImages/3586711-300_0.jpg"/>
#  <source srcset="//img4.ad.co.il/CarImages/3586711-400_0.jpg"/>
#  <img alt="" class="img-fluid" decoding="async" loading="lazy" onload="this.style.opacity = 1" src="//img4.ad.co.il/CarImages/3586711-400_0.jpg"/>
#  </picture>
#  <div class="card-body p-md-3">
#  <a href="/ad/15153584"><h2 class="card-title mb-0 mb-sm-1">טסלה מודל 3</h2></a>
#  <div class="card-text my-1 mb-1 mt-0 d-flex justify-content-between">
#  <div>
#                          2022
#                      </div>
#  <div>
#                          1%<i class="fas fa-long-arrow-alt-down ps-1 pe-2"></i>
#  <span class="text-decoration-line-through text-400"></span>
#  </div>
#  </div>
#  <div class="d-flex justify-content-between">
#  <div class="d-inline-flex">
#  <div class="me-2 flex-fill card-icon-wrapper">
#  <i class="fa fa-tachometer-alt"></i>
#  <span class="ms-1">26K<span class="d-none d-md-inline-block"> ק"מ</span></span>
#  </div>
#  <div class="flex-fill card-icon-wrapper">
#  <i class="fa fa-hand-paper"></i>
#  <span class="ms-1">2<span class="d-none d-md-inline-block"> יד</span></span>
#  </div>
#  </div>
#  <div class="price ms-1">228,000 ₪</div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card-block" data-id="15045615" data-images="4" onclick="clickad(15045615)">
#  <div class="card overflow-hidden">
#  <picture class="card-img-top picbg">
#  <source media="(max-width: 767px)" srcset="//img2.ad.co.il/CarImages/3545113-300_0.jpg"/>
#  <source srcset="//img2.ad.co.il/CarImages/3545113-400_0.jpg"/>
#  <img alt="" class="img-fluid" decoding="async" loading="lazy" onload="this.style.opacity = 1" src="//img2.ad.co.il/CarImages/3545113-400_0.jpg"/>
#  </picture>
#  <div class="card-body p-md-3">
#  <a href="/ad/15045615"><h2 class="card-title mb-0 mb-sm-1">טסלה מודל S</h2></a>
#  <p class="card-text my-1 mb-1 mt-0">
#                      2022
#                  </p>
#  <div class="d-flex justify-content-between">
#  <div class="d-inline-flex">
#  <div class="me-2 flex-fill card-icon-wrapper">
#  <i class="fa fa-tachometer-alt"></i>
#  <span class="ms-1">1K<span class="d-none d-md-inline-block"> ק"מ</span></span>
#  </div>
#  <div class="flex-fill card-icon-wrapper">
#  <i class="fa fa-hand-paper"></i>
#  <span class="ms-1">1<span class="d-none d-md-inline-block"> יד</span></span>
#  </div>
#  </div>
#  <div class="price ms-1">630,000 ₪</div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card-block" data-id="14614295" data-images="1" onclick="clickad(14614295)">
#  <div class="card overflow-hidden">
#  <picture class="card-img-top picbg">
#  <source media="(max-width: 767px)" srcset="//img4.ad.co.il/CarImages/3386251-300_0.jpg"/>
#  <source srcset="//img4.ad.co.il/CarImages/3386251-400_0.jpg"/>
#  <img alt="" class="img-fluid" decoding="async" loading="lazy" onload="this.style.opacity = 1" src="//img4.ad.co.il/CarImages/3386251-400_0.jpg"/>
#  </picture>
#  <div class="card-body p-md-3">
#  <a href="/ad/14614295"><h2 class="card-title mb-0 mb-sm-1">טסלה מודל 3</h2></a>
#  <p class="card-text my-1 mb-1 mt-0">
#                      2021
#                  </p>
#  <div class="d-flex justify-content-between">
#  <div class="d-inline-flex">
#  <div class="me-2 flex-fill card-icon-wrapper">
#  <i class="fa fa-tachometer-alt"></i>
#  <span class="ms-1">28K<span class="d-none d-md-inline-block"> ק"מ</span></span>
#  </div>
#  <div class="flex-fill card-icon-wrapper">
#  <i class="fa fa-hand-paper"></i>
#  <span class="ms-1">1<span class="d-none d-md-inline-block"> יד</span></span>
#  </div>
#  </div>
#  <div class="price ms-1">262,000 ₪</div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card-block" data-id="14599009" data-images="1" onclick="clickad(14599009)">
#  <div class="card overflow-hidden">
#  <picture class="card-img-top picbg">
#  <source media="(max-width: 767px)" srcset="//img1.ad.co.il/CarImages/3380656-300_0.jpg"/>
#  <source srcset="//img1.ad.co.il/CarImages/3380656-400_0.jpg"/>
#  <img alt="" class="img-fluid" decoding="async" loading="lazy" onload="this.style.opacity = 1" src="//img1.ad.co.il/CarImages/3380656-400_0.jpg"/>
#  </picture>
#  <div class="card-body p-md-3">
#  <a href="/ad/14599009"><h2 class="card-title mb-0 mb-sm-1">טסלה מודל 3</h2></a>
#  <p class="card-text my-1 mb-1 mt-0">
#                      2022
#                  </p>
#  <div class="d-flex justify-content-between">
#  <div class="d-inline-flex">
#  <div class="me-2 flex-fill card-icon-wrapper">
#  <i class="fa fa-tachometer-alt"></i>
#  <span class="ms-1">19K<span class="d-none d-md-inline-block"> ק"מ</span></span>
#  </div>
#  <div class="flex-fill card-icon-wrapper">
#  <i class="fa fa-hand-paper"></i>
#  <span class="ms-1">1<span class="d-none d-md-inline-block"> יד</span></span>
#  </div>
#  </div>
#  <div class="price ms-1">220,000 ₪</div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card-block" data-id="14598998" data-images="1" onclick="clickad(14598998)">
#  <div class="card overflow-hidden">
#  <picture class="card-img-top picbg">
#  <source media="(max-width: 767px)" srcset="//img4.ad.co.il/CarImages/3380647-300_0.jpg"/>
#  <source srcset="//img4.ad.co.il/CarImages/3380647-400_0.jpg"/>
#  <img alt="" class="img-fluid" decoding="async" loading="lazy" onload="this.style.opacity = 1" src="//img4.ad.co.il/CarImages/3380647-400_0.jpg"/>
#  </picture>
#  <div class="card-body p-md-3">
#  <a href="/ad/14598998"><h2 class="card-title mb-0 mb-sm-1">טסלה מודל 3</h2></a>
#  <p class="card-text my-1 mb-1 mt-0">
#                      2021
#                  </p>
#  <div class="d-flex justify-content-between">
#  <div class="d-inline-flex">
#  <div class="flex-fill card-icon-wrapper">
#  <i class="fa fa-hand-paper"></i>
#  <span class="ms-1">1<span class="d-none d-md-inline-block"> יד</span></span>
#  </div>
#  </div>
#  <div class="price ms-1">230,000 ₪</div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card-block" data-id="14559810" data-images="1" onclick="clickad(14559810)">
#  <div class="card overflow-hidden">
#  <picture class="card-img-top picbg">
#  <source media="(max-width: 767px)" srcset="//img2.ad.co.il/CarImages/3368173-300_0.jpg"/>
#  <source srcset="//img2.ad.co.il/CarImages/3368173-400_0.jpg"/>
#  <img alt="" class="img-fluid" decoding="async" loading="lazy" onload="this.style.opacity = 1" src="//img2.ad.co.il/CarImages/3368173-400_0.jpg"/>
#  </picture>
#  <div class="card-body p-md-3">
#  <a href="/ad/14559810"><h2 class="card-title mb-0 mb-sm-1">טסלה מודל 3</h2></a>
#  <p class="card-text my-1 mb-1 mt-0">
#                      2021
#                  </p>
#  <div class="d-flex justify-content-between">
#  <div class="d-inline-flex">
#  <div class="me-2 flex-fill card-icon-wrapper">
#  <i class="fa fa-tachometer-alt"></i>
#  <span class="ms-1">28K<span class="d-none d-md-inline-block"> ק"מ</span></span>
#  </div>
#  <div class="flex-fill card-icon-wrapper">
#  <i class="fa fa-hand-paper"></i>
#  <span class="ms-1">1<span class="d-none d-md-inline-block"> יד</span></span>
#  </div>
#  </div>
#  <div class="price ms-1">265,000 ₪</div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card-block" data-id="14559796" data-images="1" onclick="clickad(14559796)">
#  <div class="card overflow-hidden">
#  <picture class="card-img-top picbg">
#  <source media="(max-width: 767px)" srcset="//img1.ad.co.il/CarImages/3368164-300_0.jpg"/>
#  <source srcset="//img1.ad.co.il/CarImages/3368164-400_0.jpg"/>
#  <img alt="" class="img-fluid" decoding="async" loading="lazy" onload="this.style.opacity = 1" src="//img1.ad.co.il/CarImages/3368164-400_0.jpg"/>
#  </picture>
#  <div class="card-body p-md-3">
#  <a href="/ad/14559796"><h2 class="card-title mb-0 mb-sm-1">טסלה מודל 3</h2></a>
#  <p class="card-text my-1 mb-1 mt-0">
#                      2021
#                  </p>
#  <div class="d-flex justify-content-between">
#  <div class="d-inline-flex">
#  <div class="me-2 flex-fill card-icon-wrapper">
#  <i class="fa fa-tachometer-alt"></i>
#  <span class="ms-1">22K<span class="d-none d-md-inline-block"> ק"מ</span></span>
#  </div>
#  <div class="flex-fill card-icon-wrapper">
#  <i class="fa fa-hand-paper"></i>
#  <span class="ms-1">1<span class="d-none d-md-inline-block"> יד</span></span>
#  </div>
#  </div>
#  <div class="price ms-1">214,000 ₪</div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card-block" data-id="14436349" data-images="1" onclick="clickad(14436349)">
#  <div class="card overflow-hidden">
#  <picture class="card-img-top picbg">
#  <source media="(max-width: 767px)" srcset="//img3.ad.co.il/CarImages/3322778-300_0.jpg"/>
#  <source srcset="//img3.ad.co.il/CarImages/3322778-400_0.jpg"/>
#  <img alt="" class="img-fluid" decoding="async" loading="lazy" onload="this.style.opacity = 1" src="//img3.ad.co.il/CarImages/3322778-400_0.jpg"/>
#  </picture>
#  <div class="card-body p-md-3">
#  <a href="/ad/14436349"><h2 class="card-title mb-0 mb-sm-1">טסלה מודל 3</h2></a>
#  <p class="card-text my-1 mb-1 mt-0">
#                      2021
#                  </p>
#  <div class="d-flex justify-content-between">
#  <div class="d-inline-flex">
#  <div class="me-2 flex-fill card-icon-wrapper">
#  <i class="fa fa-tachometer-alt"></i>
#  <span class="ms-1">10K<span class="d-none d-md-inline-block"> ק"מ</span></span>
#  </div>
#  <div class="flex-fill card-icon-wrapper">
#  <i class="fa fa-hand-paper"></i>
#  <span class="ms-1">1<span class="d-none d-md-inline-block"> יד</span></span>
#  </div>
#  </div>
#  <div class="price ms-1">220,000 ₪</div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card-block" data-id="14408560" data-images="1" onclick="clickad(14408560)">
#  <div class="card overflow-hidden">
#  <picture class="card-img-top picbg">
#  <source media="(max-width: 767px)" srcset="//img4.ad.co.il/CarImages/3314419-300_0.jpg"/>
#  <source srcset="//img4.ad.co.il/CarImages/3314419-400_0.jpg"/>
#  <img alt="" class="img-fluid" decoding="async" loading="lazy" onload="this.style.opacity = 1" src="//img4.ad.co.il/CarImages/3314419-400_0.jpg"/>
#  </picture>
#  <div class="card-body p-md-3">
#  <a href="/ad/14408560"><h2 class="card-title mb-0 mb-sm-1">טסלה מודל 3</h2></a>
#  <p class="card-text my-1 mb-1 mt-0">
#                      2021
#                  </p>
#  <div class="d-flex justify-content-between">
#  <div class="d-inline-flex">
#  <div class="me-2 flex-fill card-icon-wrapper">
#  <i class="fa fa-tachometer-alt"></i>
#  <span class="ms-1">40K<span class="d-none d-md-inline-block"> ק"מ</span></span>
#  </div>
#  <div class="flex-fill card-icon-wrapper">
#  <i class="fa fa-hand-paper"></i>
#  <span class="ms-1">1<span class="d-none d-md-inline-block"> יד</span></span>
#  </div>
#  </div>
#  <div class="price ms-1">248,350 ₪</div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card-block" data-id="14399059" data-images="1" onclick="clickad(14399059)">
#  <div class="card overflow-hidden">
#  <picture class="card-img-top picbg">
#  <source media="(max-width: 767px)" srcset="//img4.ad.co.il/CarImages/3309775-300_0.jpg"/>
#  <source srcset="//img4.ad.co.il/CarImages/3309775-400_0.jpg"/>
#  <img alt="" class="img-fluid" decoding="async" loading="lazy" onload="this.style.opacity = 1" src="//img4.ad.co.il/CarImages/3309775-400_0.jpg"/>
#  </picture>
#  <div class="card-body p-md-3">
#  <a href="/ad/14399059"><h2 class="card-title mb-0 mb-sm-1">טסלה מודל 3</h2></a>
#  <p class="card-text my-1 mb-1 mt-0">
#                      2021
#                  </p>
#  <div class="d-flex justify-content-between">
#  <div class="d-inline-flex">
#  <div class="me-2 flex-fill card-icon-wrapper">
#  <i class="fa fa-tachometer-alt"></i>
#  <span class="ms-1">23K<span class="d-none d-md-inline-block"> ק"מ</span></span>
#  </div>
#  <div class="flex-fill card-icon-wrapper">
#  <i class="fa fa-hand-paper"></i>
#  <span class="ms-1">1<span class="d-none d-md-inline-block"> יד</span></span>
#  </div>
#  </div>
#  <div class="price ms-1">285,000 ₪</div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card-block" data-id="14138122" data-images="1" onclick="clickad(14138122)">
#  <div class="card overflow-hidden">
#  <picture class="card-img-top picbg">
#  <source media="(max-width: 767px)" srcset="//img4.ad.co.il/CarImages/3223251-300_0.jpg"/>
#  <source srcset="//img4.ad.co.il/CarImages/3223251-400_0.jpg"/>
#  <img alt="" class="img-fluid" decoding="async" loading="lazy" onload="this.style.opacity = 1" src="//img4.ad.co.il/CarImages/3223251-400_0.jpg"/>
#  </picture>
#  <div class="card-body p-md-3">
#  <a href="/ad/14138122"><h2 class="card-title mb-0 mb-sm-1">טסלה מודל 3</h2></a>
#  <p class="card-text my-1 mb-1 mt-0">
#                      2021
#                  </p>
#  <div class="d-flex justify-content-between">
#  <div class="d-inline-flex">
#  <div class="me-2 flex-fill card-icon-wrapper">
#  <i class="fa fa-tachometer-alt"></i>
#  <span class="ms-1">19K<span class="d-none d-md-inline-block"> ק"מ</span></span>
#  </div>
#  <div class="flex-fill card-icon-wrapper">
#  <i class="fa fa-hand-paper"></i>
#  <span class="ms-1">1<span class="d-none d-md-inline-block"> יד</span></span>
#  </div>
#  </div>
#  <div class="price ms-1">300,000 ₪</div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card-block" data-id="13706938" data-images="1" onclick="clickad(13706938)">
#  <div class="card overflow-hidden">
#  <picture class="card-img-top picbg">
#  <source media="(max-width: 767px)" srcset="//img3.ad.co.il/CarImages/3086562-300_0.jpg"/>
#  <source srcset="//img3.ad.co.il/CarImages/3086562-400_0.jpg"/>
#  <img alt="" class="img-fluid" decoding="async" loading="lazy" onload="this.style.opacity = 1" src="//img3.ad.co.il/CarImages/3086562-400_0.jpg"/>
#  </picture>
#  <div class="card-body p-md-3">
#  <a href="/ad/13706938"><h2 class="card-title mb-0 mb-sm-1">טסלה מודל 3</h2></a>
#  <p class="card-text my-1 mb-1 mt-0">
#                      2021
#                  </p>
#  <div class="d-flex justify-content-between">
#  <div class="d-inline-flex">
#  <div class="me-2 flex-fill card-icon-wrapper">
#  <i class="fa fa-tachometer-alt"></i>
#  <span class="ms-1">9K<span class="d-none d-md-inline-block"> ק"מ</span></span>
#  </div>
#  <div class="flex-fill card-icon-wrapper">
#  <i class="fa fa-hand-paper"></i>
#  <span class="ms-1">1<span class="d-none d-md-inline-block"> יד</span></span>
#  </div>
#  </div>
#  <div class="price ms-1">295,000 ₪</div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card-block" data-id="13461784" data-images="1" onclick="clickad(13461784)">
#  <div class="card overflow-hidden">
#  <picture class="card-img-top picbg">
#  <source media="(max-width: 767px)" srcset="//img2.ad.co.il/CarImages/2996777-300_0.jpg"/>
#  <source srcset="//img2.ad.co.il/CarImages/2996777-400_0.jpg"/>
#  <img alt="" class="img-fluid" decoding="async" loading="lazy" onload="this.style.opacity = 1" src="//img2.ad.co.il/CarImages/2996777-400_0.jpg"/>
#  </picture>
#  <div class="card-body p-md-3">
#  <a href="/ad/13461784"><h2 class="card-title mb-0 mb-sm-1">טסלה מודל 3</h2></a>
#  <p class="card-text my-1 mb-1 mt-0">
#                      2021
#                  </p>
#  <div class="d-flex justify-content-between">
#  <div class="d-inline-flex">
#  <div class="me-2 flex-fill card-icon-wrapper">
#  <i class="fa fa-tachometer-alt"></i>
#  <span class="ms-1">14K<span class="d-none d-md-inline-block"> ק"מ</span></span>
#  </div>
#  <div class="flex-fill card-icon-wrapper">
#  <i class="fa fa-hand-paper"></i>
#  <span class="ms-1">1<span class="d-none d-md-inline-block"> יד</span></span>
#  </div>
#  </div>
#  <div class="price ms-1">222,000 ₪</div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card-block" data-id="13437492" data-images="1" onclick="clickad(13437492)">
#  <div class="card overflow-hidden">
#  <picture class="card-img-top picbg">
#  <source media="(max-width: 767px)" srcset="//img4.ad.co.il/CarImages/2986471-300_0.jpg"/>
#  <source srcset="//img4.ad.co.il/CarImages/2986471-400_0.jpg"/>
#  <img alt="" class="img-fluid" decoding="async" loading="lazy" onload="this.style.opacity = 1" src="//img4.ad.co.il/CarImages/2986471-400_0.jpg"/>
#  </picture>
#  <div class="card-body p-md-3">
#  <a href="/ad/13437492"><h2 class="card-title mb-0 mb-sm-1">טסלה מודל 3</h2></a>
#  <p class="card-text my-1 mb-1 mt-0">
#                      2022
#                  </p>
#  <div class="d-flex justify-content-between">
#  <div class="d-inline-flex">
#  <div class="flex-fill card-icon-wrapper">
#  <i class="fa fa-hand-paper"></i>
#  <span class="ms-1">1<span class="d-none d-md-inline-block"> יד</span></span>
#  </div>
#  </div>
#  <div class="price ms-1">225,000 ₪</div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card-block" data-id="13437491" data-images="1" onclick="clickad(13437491)">
#  <div class="card overflow-hidden">
#  <picture class="card-img-top picbg">
#  <source media="(max-width: 767px)" srcset="//img3.ad.co.il/CarImages/2986470-300_0.jpg"/>
#  <source srcset="//img3.ad.co.il/CarImages/2986470-400_0.jpg"/>
#  <img alt="" class="img-fluid" decoding="async" loading="lazy" onload="this.style.opacity = 1" src="//img3.ad.co.il/CarImages/2986470-400_0.jpg"/>
#  </picture>
#  <div class="card-body p-md-3">
#  <a href="/ad/13437491"><h2 class="card-title mb-0 mb-sm-1">טסלה מודל 3</h2></a>
#  <p class="card-text my-1 mb-1 mt-0">
#                      2022
#                  </p>
#  <div class="d-flex justify-content-between">
#  <div class="d-inline-flex">
#  <div class="flex-fill card-icon-wrapper">
#  <i class="fa fa-hand-paper"></i>
#  <span class="ms-1">1<span class="d-none d-md-inline-block"> יד</span></span>
#  </div>
#  </div>
#  <div class="price ms-1">220,000 ₪</div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card-block" data-id="13437488" data-images="1" onclick="clickad(13437488)">
#  <div class="card overflow-hidden">
#  <picture class="card-img-top picbg">
#  <source media="(max-width: 767px)" srcset="//img2.ad.co.il/CarImages/2986469-300_0.jpg"/>
#  <source srcset="//img2.ad.co.il/CarImages/2986469-400_0.jpg"/>
#  <img alt="" class="img-fluid" decoding="async" loading="lazy" onload="this.style.opacity = 1" src="//img2.ad.co.il/CarImages/2986469-400_0.jpg"/>
#  </picture>
#  <div class="card-body p-md-3">
#  <a href="/ad/13437488"><h2 class="card-title mb-0 mb-sm-1">טסלה מודל 3</h2></a>
#  <p class="card-text my-1 mb-1 mt-0">
#                      2022
#                  </p>
#  <div class="d-flex justify-content-between">
#  <div class="d-inline-flex">
#  <div class="flex-fill card-icon-wrapper">
#  <i class="fa fa-hand-paper"></i>
#  <span class="ms-1">1<span class="d-none d-md-inline-block"> יד</span></span>
#  </div>
#  </div>
#  <div class="price ms-1">290,000 ₪</div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card-block" data-id="12883785" data-images="9" onclick="clickad(12883785)">
#  <div class="card overflow-hidden">
#  <picture class="card-img-top picbg">
#  <source media="(max-width: 767px)" srcset="//img4.ad.co.il/CarImages/2795075-300_0.jpg"/>
#  <source srcset="//img4.ad.co.il/CarImages/2795075-400_0.jpg"/>
#  <img alt="" class="img-fluid" decoding="async" loading="lazy" onload="this.style.opacity = 1" src="//img4.ad.co.il/CarImages/2795075-400_0.jpg"/>
#  </picture>
#  <div class="card-body p-md-3">
#  <a href="/ad/12883785"><h2 class="card-title mb-0 mb-sm-1">טסלה מודל X</h2></a>
#  <p class="card-text my-1 mb-1 mt-0">
#                      2021
#                  </p>
#  <div class="d-flex justify-content-between">
#  <div class="d-inline-flex">
#  <div class="me-2 flex-fill card-icon-wrapper">
#  <i class="fa fa-tachometer-alt"></i>
#  <span class="ms-1">6K<span class="d-none d-md-inline-block"> ק"מ</span></span>
#  </div>
#  <div class="flex-fill card-icon-wrapper">
#  <i class="fa fa-hand-paper"></i>
#  <span class="ms-1">1<span class="d-none d-md-inline-block"> יד</span></span>
#  </div>
#  </div>
#  <div class="price ms-1">340,000 ₪</div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card-block" data-id="12888758" data-images="11" onclick="clickad(12888758)">
#  <div class="card overflow-hidden">
#  <picture class="card-img-top picbg">
#  <source media="(max-width: 767px)" srcset="//img3.ad.co.il/CarImages/2796826-300_0.jpg"/>
#  <source srcset="//img3.ad.co.il/CarImages/2796826-400_0.jpg"/>
#  <img alt="" class="img-fluid" decoding="async" loading="lazy" onload="this.style.opacity = 1" src="//img3.ad.co.il/CarImages/2796826-400_0.jpg"/>
#  </picture>
#  <div class="card-body p-md-3">
#  <a href="/ad/12888758"><h2 class="card-title mb-0 mb-sm-1">טסלה מודל X</h2></a>
#  <p class="card-text my-1 mb-1 mt-0">
#                      2021
#                  </p>
#  <div class="d-flex justify-content-between">
#  <div class="d-inline-flex">
#  <div class="flex-fill card-icon-wrapper">
#  <i class="fa fa-hand-paper"></i>
#  <span class="ms-1">1<span class="d-none d-md-inline-block"> יד</span></span>
#  </div>
#  </div>
#  <div class="price ms-1">355,000 ₪</div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card-block" data-id="15158349" data-images="10" onclick="clickad(15158349)">
#  <div class="card overflow-hidden">
#  <picture class="card-img-top picbg">
#  <source media="(max-width: 767px)" srcset="//img4.ad.co.il/CarImages/3588411-300_0.jpg"/>
#  <source srcset="//img4.ad.co.il/CarImages/3588411-400_0.jpg"/>
#  <img alt="" class="img-fluid" decoding="async" loading="lazy" onload="this.style.opacity = 1" src="//img4.ad.co.il/CarImages/3588411-400_0.jpg"/>
#  </picture>
#  <div class="card-body p-md-3">
#  <a href="/ad/15158349"><h2 class="card-title mb-0 mb-sm-1">טסלה מודל 3</h2></a>
#  <p class="card-text my-1 mb-1 mt-0">
#                      2022
#                  </p>
#  <div class="d-flex justify-content-between">
#  <div class="d-inline-flex">
#  <div class="flex-fill card-icon-wrapper">
#  <i class="fa fa-hand-paper"></i>
#  <span class="ms-1">1<span class="d-none d-md-inline-block"> יד</span></span>
#  </div>
#  </div>
#  <div class="price ms-1">206,000 ₪</div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card-block" data-id="14967783" data-images="0" onclick="clickad(14967783)">
#  <div class="card overflow-hidden">
#  <div class="picbg picture-filler picture-grid-filler"></div>
#  <div class="card-body p-md-3">
#  <a href="/ad/14967783"><h2 class="card-title mb-0 mb-sm-1">טסלה מודל 3</h2></a>
#  <p class="card-text my-1 mb-1 mt-0">
#                      2022
#                  </p>
#  <div class="d-flex justify-content-between">
#  <div class="d-inline-flex">
#  <div class="me-2 flex-fill card-icon-wrapper">
#  <i class="fa fa-tachometer-alt"></i>
#  <span class="ms-1">3K<span class="d-none d-md-inline-block"> ק"מ</span></span>
#  </div>
#  <div class="flex-fill card-icon-wrapper">
#  <i class="fa fa-hand-paper"></i>
#  <span class="ms-1">1<span class="d-none d-md-inline-block"> יד</span></span>
#  </div>
#  </div>
#  <div class="price ms-1">230,000 ₪</div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card-block" data-id="14241376" data-images="0" onclick="clickad(14241376)">
#  <div class="card overflow-hidden">
#  <div class="picbg picture-filler picture-grid-filler"></div>
#  <div class="card-body p-md-3">
#  <a href="/ad/14241376"><h2 class="card-title mb-0 mb-sm-1">טסלה מודל 3</h2></a>
#  <p class="card-text my-1 mb-1 mt-0">
#                      2021
#                  </p>
#  <div class="d-flex justify-content-between">
#  <div class="d-inline-flex">
#  <div class="me-2 flex-fill card-icon-wrapper">
#  <i class="fa fa-tachometer-alt"></i>
#  <span class="ms-1">10K<span class="d-none d-md-inline-block"> ק"מ</span></span>
#  </div>
#  <div class="flex-fill card-icon-wrapper">
#  <i class="fa fa-hand-paper"></i>
#  <span class="ms-1">1<span class="d-none d-md-inline-block"> יד</span></span>
#  </div>
#  </div>
#  <div class="price"> </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card-block" data-id="13603674" data-images="0" onclick="clickad(13603674)">
#  <div class="card overflow-hidden">
#  <div class="picbg picture-filler picture-grid-filler"></div>
#  <div class="card-body p-md-3">
#  <a href="/ad/13603674"><h2 class="card-title mb-0 mb-sm-1">טסלה מודל 3</h2></a>
#  <p class="card-text my-1 mb-1 mt-0">
#                      2022
#                  </p>
#  <div class="d-flex justify-content-between">
#  <div class="d-inline-flex">
#  <div class="flex-fill card-icon-wrapper">
#  <i class="fa fa-hand-paper"></i>
#  <span class="ms-1">1<span class="d-none d-md-inline-block"> יד</span></span>
#  </div>
#  </div>
#  <div class="price ms-1">10,000 ₪</div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card-block footer-cards mb-3" onclick="clickad(16186906, true)">
#  <div class="card overflow-hidden">
#  <picture class="card-img-top">
#  <source srcset="//img3.ad.co.il/NadlanRentImages/2939182_0.jpg?w=250&amp;h=192"/>
#  <img alt="" class="img-fluid" loading="lazy" onload="this.style.opacity = 1" src="//img3.ad.co.il/NadlanRentImages/2939182_0.jpg?w=250&amp;h=192"/>
#  </picture>
#  <div class="card-body p-md-3">
#  <div class="card-body-wrap">
#  <a href="/ad/16186906"><h2 class="card-title mb-1 text-info">בת ים בית וגן</h2></a>
#  <p class="card-text my-1 mb-1 mt-0">ההגנה</p>
#  <div class="price text-start">4,000 ₪</div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card-block footer-cards mb-3" onclick="clickad(16188721, true)">
#  <div class="card overflow-hidden">
#  <picture class="card-img-top">
#  <source srcset="//img3.ad.co.il/NadlanRentImages/2939286_0.jpg?w=250&amp;h=192"/>
#  <img alt="" class="img-fluid" loading="lazy" onload="this.style.opacity = 1" src="//img3.ad.co.il/NadlanRentImages/2939286_0.jpg?w=250&amp;h=192"/>
#  </picture>
#  <div class="card-body p-md-3">
#  <div class="card-body-wrap">
#  <a href="/ad/16188721"><h2 class="card-title mb-1 text-info">אילת אופיר</h2></a>
#  <p class="card-text my-1 mb-1 mt-0">ערבה 30</p>
#  <div class="price text-start">7,400 ₪</div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card-block footer-cards mb-3" onclick="clickad(16186492, true)">
#  <div class="card overflow-hidden">
#  <picture class="card-img-top">
#  <source srcset="//img2.ad.co.il/NadlanSaleImages/2233689_0.jpg?w=250&amp;h=192"/>
#  <img alt="" class="img-fluid" loading="lazy" onload="this.style.opacity = 1" src="//img2.ad.co.il/NadlanSaleImages/2233689_0.jpg?w=250&amp;h=192"/>
#  </picture>
#  <div class="card-body p-md-3">
#  <div class="card-body-wrap">
#  <a href="/ad/16186492"><h2 class="card-title mb-1 text-info">תל אביב יפו שיכון בבלי</h2></a>
#  <p class="card-text my-1 mb-1 mt-0">בבלי</p>
#  <div class="price text-start">10,000,000 ₪</div>
#  </div>
#  </div>
#  </div>
#  </div>]

# %%
manufacturer = soup.find('li',{'class':'breadcrumb-item active'}).find('span').get_text()
manufacturer
# Out:
# 'טסלה'

# %%
url = "https://www.ad.co.il/car?keyword=" + manufacturer
response = requests.get(url)
results_page = BeautifulSoup(response.content, 'html.parser')

# %%
def fetch_tesla_cars(keywords):
    tesla_list = list()
    import requests
    from bs4 import BeautifulSoup
    url = "https://www.ad.co.il/car?keyword=" + keywords
    response = requests.get(url)
    if not response.status_code == 200:
        print ("not 200")
        return None
    try:
        results_page = BeautifulSoup(response.content, 'html.parser')
        cars = results_page.find_all('div',{'class':'card-body p-md-3'})
        for car in cars:
            car_link = "https://www.ad.co.il" + car.find('a').get('href')
            car_name = car.find('a').get_text()
            
            if keywords in car_name:
                tesla_list.append((car_link)) 
        return tesla_list
    except:
        return None

# %%
fetch_tesla_cars(manufactor)
# Out:
# ['https://www.ad.co.il/ad/16186570',
#  'https://www.ad.co.il/ad/16067490',
#  'https://www.ad.co.il/ad/16146497',
#  'https://www.ad.co.il/ad/15904463',
#  'https://www.ad.co.il/ad/15884168',
#  'https://www.ad.co.il/ad/15789782',
#  'https://www.ad.co.il/ad/15443695',
#  'https://www.ad.co.il/ad/15153584',
#  'https://www.ad.co.il/ad/15045615',
#  'https://www.ad.co.il/ad/14614295',
#  'https://www.ad.co.il/ad/14599009',
#  'https://www.ad.co.il/ad/14598998',
#  'https://www.ad.co.il/ad/14559810',
#  'https://www.ad.co.il/ad/14559796',
#  'https://www.ad.co.il/ad/14436349',
#  'https://www.ad.co.il/ad/14408560',
#  'https://www.ad.co.il/ad/14399059',
#  'https://www.ad.co.il/ad/14138122',
#  'https://www.ad.co.il/ad/13706938',
#  'https://www.ad.co.il/ad/13461784',
#  'https://www.ad.co.il/ad/13437492',
#  'https://www.ad.co.il/ad/13437491',
#  'https://www.ad.co.il/ad/13437488',
#  'https://www.ad.co.il/ad/12883785',
#  'https://www.ad.co.il/ad/12888758',
#  'https://www.ad.co.il/ad/15158349',
#  'https://www.ad.co.il/ad/14967783',
#  'https://www.ad.co.il/ad/14241376',
#  'https://www.ad.co.il/ad/13603674']

# %%
def fetch_details(car_link):
    from datetime import datetime
    tesla_dict = {}
    counter = 0

    try:
        response = requests.get(car_link)
        if not response.status_code == 200:
            return "str"
        result_page = BeautifulSoup(response.content, 'html.parser')

        table = result_page.find('table', {'class': 'table table-sm mb-4'}).find('tbody')
        for tr in table.find_all("tr"):
            td = tr.find_all('td')

            key = td[0].get_text().strip()
            value = td[1].get_text().strip()
            if key == "שנה":
                value = int(value)
            elif key == "יד":
                value = int(value)
            elif key == "Pic_num":
                value = int(value)
            elif key == "נפח":
                value = int(''.join(filter(str.isdigit, value)))

            tesla_dict[key] = value

        picture = result_page.find_all('div', {'class': 'justify-content-center px-1'})
        tesla_dict['Pic_num'] = int(len(picture))

        model_and_price = result_page.find_all('h2', {'class': 'card-title'})
        tesla_dict['Price'] = model_and_price[1].get_text().strip().replace('₪', '')
        tesla_dict['model'] = model_and_price[0].get_text()

        Repub_date_and_Cre_date = result_page.find_all('div', {'class': 'px-3'})
        cre_date = Repub_date_and_Cre_date[0].get_text().split()
        Repub_date = Repub_date_and_Cre_date[1].get_text().split()
        tesla_dict['Cre_date'] = cre_date[2]
        tesla_dict['Repub_date'] = Repub_date[3]
        datetime.strptime(car_dict['Cre_date'], "%Y-%m-%d")
        datetime.strptime(car_dict['Repub_date'], "%Y-%m-%d")
        tesla_dict["manufacturer"] = "טסלה"

        description = result_page.find('p', {'class': 'text-word-break'}).get_text()

        return tesla_dict
    except:
        return tesla_dict

# %%
fetch_details('https://www.ad.co.il/ad/16186570')
# Out:
# {'שנה': 2021,
#  'יד': 1,
#  'ת. הילוכים': 'אוטומטית',
#  'נפח': 6000,
#  'סוג מנוע': 'חשמלי',
#  'ק"מ': '48,000',
#  'טסט עד': '06/2025',
#  'צבע': 'שחור',
#  'בעלות קודמת': 'פרטית',
#  'בעלות נוכחית': 'פרטית',
#  'אזור': 'ראשל"צ והסביבה',
#  'עיר': 'באר יעקב',
#  'Pic_num': 10,
#  'Price': '190,000 ',
#  'model': 'טסלה מודל 3',
#  'Cre_date': '20/05/2024',
#  'Repub_date': '26/05/2024'}

# %%
def fetch_all(keywords):
    results = list()
    all_teslas = fetch_tesla_cars(keywords)
    for car in all_teslas:
        t = fetch_details(car)
        results.append(t)
        
    return results

# %%
tesla = fetch_all(manufacturer)

# %%
tesla
# Out:
# [{'שנה': 2021,
#   'יד': 1,
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': 6000,
#   'סוג מנוע': 'חשמלי',
#   'ק"מ': '48,000',
#   'טסט עד': '06/2025',
#   'צבע': 'שחור',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'ראשל"צ והסביבה',
#   'עיר': 'באר יעקב',
#   'Pic_num': 10,
#   'Price': '190,000 ',
#   'model': 'טסלה מודל 3',
#   'Cre_date': '20/05/2024',
#   'Repub_date': '26/05/2024'},
#  {'שנה': 2022,
#   'יד': 1,
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': 800,
#   'סוג מנוע': 'חשמלי',
#   'ק"מ': '33,000',
#   'צבע': 'לבן',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'רעננה - כפר סבא',
#   'עיר': 'כפר סבא',
#   'Pic_num': 10,
#   'Price': '145,000 ',
#   'model': 'טסלה מודל 3',
#   'Cre_date': '21/01/2024',
#   'Repub_date': '22/05/2024'},
#  {'שנה': 2018,
#   'יד': 2,
#   'ת. הילוכים': 'רובוטית',
#   'נפח': 1000,
#   'סוג מנוע': 'חשמלי',
#   'צבע': 'שחור',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'רמת גן - גבעתיים',
#   'עיר': 'בני ברק',
#   'Pic_num': 5,
#   'Price': '13,000 ',
#   'model': 'טסלה מודל S',
#   'Cre_date': '22/03/2024',
#   'Repub_date': '22/03/2024'},
#  {'שנה': 2021,
#   'יד': 2,
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': 4900,
#   'סוג מנוע': 'חשמלי',
#   'ק"מ': '79,000',
#   'צבע': 'לבן פנינה',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'נס ציונה - רחובות',
#   'עיר': 'רחובות',
#   'Pic_num': 4,
#   'Price': '179,000 ',
#   'model': 'טסלה מודל 3',
#   'Cre_date': '02/09/2023',
#   'Repub_date': '02/09/2023'},
#  {'שנה': 2023,
#   'יד': 2,
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': 6000,
#   'סוג מנוע': 'חשמלי',
#   'ק"מ': '1,900',
#   'צבע': 'לבן פנינה',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'ירושלים והסביבה',
#   'עיר': 'ירושלים',
#   'Pic_num': 1,
#   'Price': '225,000 ',
#   'model': 'טסלה מודל 3',
#   'Cre_date': '16/08/2023',
#   'Repub_date': '16/08/2023'},
#  {'שנה': 2023,
#   'יד': 1,
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': 3000,
#   'סוג מנוע': 'חשמלי',
#   'צבע': 'לבן שנהב',
#   'בעלות קודמת': 'חברה',
#   'בעלות נוכחית': 'חברה',
#   'אזור': 'חדרה וישובי עמק חפר',
#   'עיר': 'חדרה',
#   'Pic_num': 8,
#   'Price': '280,000 ',
#   'model': 'טסלה מודל X',
#   'Cre_date': '16/06/2023',
#   'Repub_date': '16/06/2023'},
#  {'שנה': 2021,
#   'יד': 1,
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': 5000,
#   'סוג מנוע': 'חשמלי',
#   'ק"מ': '59,000',
#   'צבע': 'לבן פנינה',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'עמק יזרעאל',
#   'עיר': 'קרית טבעון',
#   'Pic_num': 2,
#   'Price': '180,000 ',
#   'model': 'טסלה מודל 3',
#   'Cre_date': '10/04/2023',
#   'Repub_date': '14/04/2023'},
#  {'שנה': 2022,
#   'יד': 2,
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': 6000,
#   'סוג מנוע': 'חשמלי',
#   'ק"מ': '26,000',
#   'צבע': 'כחול',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'רמת גן - גבעתיים',
#   'עיר': 'רמת גן',
#   'Pic_num': 3,
#   'Price': '228,000 ',
#   'model': 'טסלה מודל 3',
#   'Cre_date': '08/02/2023',
#   'Repub_date': '14/02/2023'},
#  {'שנה': 2022,
#   'יד': 1,
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': 6000,
#   'סוג מנוע': 'חשמלי',
#   'ק"מ': '1,500',
#   'צבע': 'לבן פנינה',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'ירושלים והסביבה',
#   'עיר': 'שורש',
#   'Pic_num': 4,
#   'Price': '630,000 ',
#   'model': 'טסלה מודל S',
#   'Cre_date': '18/01/2023',
#   'Repub_date': '18/01/2023'},
#  {'שנה': 2021,
#   'יד': 1,
#   'ת. הילוכים': 'אוטומטית',
#   'סוג מנוע': 'חשמלי',
#   'ק"מ': '28,000',
#   'אזור': 'באר שבע והסביבה',
#   'עיר': 'באר שבע',
#   'Pic_num': 1,
#   'Price': '262,000 ',
#   'model': 'טסלה מודל 3',
#   'Cre_date': '17/10/2022',
#   'Repub_date': '17/10/2022'},
#  {'שנה': 2022,
#   'יד': 1,
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': 1234,
#   'סוג מנוע': 'חשמלי',
#   'ק"מ': '19,000',
#   'אזור': 'מודיעין והסביבה',
#   'עיר': 'מודיעין מכבים רעות',
#   'Pic_num': 1,
#   'Price': '220,000 ',
#   'model': 'טסלה מודל 3',
#   'Cre_date': '13/10/2022',
#   'Repub_date': '13/10/2022'},
#  {'שנה': 2021,
#   'יד': 1,
#   'ת. הילוכים': 'אוטומטית',
#   'סוג מנוע': 'חשמלי',
#   'אזור': 'אשדוד - אשקלון',
#   'עיר': 'תלמי יפה',
#   'Pic_num': 1,
#   'Price': '230,000 ',
#   'model': 'טסלה מודל 3',
#   'Cre_date': '13/10/2022',
#   'Repub_date': '13/10/2022'},
#  {'שנה': 2021,
#   'יד': 1,
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': 5,
#   'סוג מנוע': 'חשמלי',
#   'ק"מ': '28,500',
#   'עיר': 'Ofaqim',
#   'Pic_num': 1,
#   'Price': '265,000 ',
#   'model': 'טסלה מודל 3',
#   'Cre_date': '03/10/2022',
#   'Repub_date': '03/10/2022'},
#  {'שנה': 2021,
#   'יד': 1,
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': 325,
#   'סוג מנוע': 'חשמלי',
#   'ק"מ': '22,000',
#   'אזור': 'אילת והערבה',
#   'עיר': 'אילת',
#   'Pic_num': 1,
#   'Price': '214,000 ',
#   'model': 'טסלה מודל 3',
#   'Cre_date': '03/10/2022',
#   'Repub_date': '03/10/2022'},
#  {'שנה': 2021,
#   'יד': 1,
#   'ת. הילוכים': 'אוטומטית',
#   'סוג מנוע': 'חשמלי',
#   'ק"מ': '10,000',
#   'אזור': 'הוד השרון והסביבה',
#   'עיר': 'הוד השרון',
#   'Pic_num': 1,
#   'Price': '220,000 ',
#   'model': 'טסלה מודל 3',
#   'Cre_date': '06/09/2022',
#   'Repub_date': '06/09/2022'},
#  {'שנה': 2021,
#   'יד': 1,
#   'ת. הילוכים': 'אוטומטית',
#   'סוג מנוע': 'חשמלי',
#   'ק"מ': '40,000',
#   'אזור': 'מודיעין והסביבה',
#   'עיר': 'מודיעין מכבים רעות',
#   'Pic_num': 1,
#   'Price': '248,350 ',
#   'model': 'טסלה מודל 3',
#   'Cre_date': '31/08/2022',
#   'Repub_date': '31/08/2022'},
#  {'שנה': 2021,
#   'יד': 1,
#   'ת. הילוכים': 'אוטומטית',
#   'סוג מנוע': 'חשמלי',
#   'ק"מ': '23,000',
#   'אזור': 'רעננה - כפר סבא',
#   'עיר': 'כפר סבא',
#   'Pic_num': 1,
#   'Price': '285,000 ',
#   'model': 'טסלה מודל 3',
#   'Cre_date': '29/08/2022',
#   'Repub_date': '29/08/2022'},
#  {'שנה': 2021,
#   'יד': 1,
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': 50000,
#   'סוג מנוע': 'חשמלי',
#   'ק"מ': '19,000',
#   'אזור': 'רעננה - כפר סבא',
#   'עיר': 'כפר סבא',
#   'Pic_num': 1,
#   'Price': '300,000 ',
#   'model': 'טסלה מודל 3',
#   'Cre_date': '08/07/2022',
#   'Repub_date': '08/07/2022'},
#  {'שנה': 2021,
#   'יד': 1,
#   'ת. הילוכים': 'אוטומטית',
#   'סוג מנוע': 'חשמלי',
#   'ק"מ': '9,000',
#   'אזור': 'חולון - בת ים',
#   'עיר': 'בת ים',
#   'Pic_num': 1,
#   'Price': '295,000 ',
#   'model': 'טסלה מודל 3',
#   'Cre_date': '20/04/2022',
#   'Repub_date': '20/04/2022'},
#  {'שנה': 2021,
#   'יד': 1,
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': 3600,
#   'סוג מנוע': 'חשמלי',
#   'ק"מ': '14,000',
#   'צבע': 'לבן מטאלי',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'באר שבע והסביבה',
#   'עיר': 'דימונה',
#   'Pic_num': 1,
#   'Price': '222,000 ',
#   'model': 'טסלה מודל 3',
#   'Cre_date': '07/02/2022',
#   'Repub_date': '07/02/2022'},
#  {'שנה': 2022,
#   'יד': 1,
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': 4500,
#   'סוג מנוע': 'חשמלי',
#   'צבע': 'לבן פנינה',
#   'בעלות קודמת': 'אחר',
#   'בעלות נוכחית': 'אחר',
#   'אזור': 'ירושלים והסביבה',
#   'עיר': 'ירושלים',
#   'Pic_num': 1,
#   'Price': '225,000 ',
#   'model': 'טסלה מודל 3',
#   'Cre_date': '31/01/2022',
#   'Repub_date': '31/01/2022'},
#  {'שנה': 2022,
#   'יד': 1,
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': 4500,
#   'סוג מנוע': 'חשמלי',
#   'צבע': 'לבן פנינה',
#   'בעלות קודמת': 'אחר',
#   'בעלות נוכחית': 'אחר',
#   'אזור': 'ירושלים והסביבה',
#   'עיר': 'ירושלים',
#   'Pic_num': 1,
#   'Price': '220,000 ',
#   'model': 'טסלה מודל 3',
#   'Cre_date': '31/01/2022',
#   'Repub_date': '31/01/2022'},
#  {'שנה': 2022,
#   'יד': 1,
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': 4500,
#   'סוג מנוע': 'חשמלי',
#   'צבע': 'לבן פנינה',
#   'בעלות קודמת': 'אחר',
#   'בעלות נוכחית': 'אחר',
#   'אזור': 'ירושלים והסביבה',
#   'עיר': 'ירושלים',
#   'Pic_num': 1,
#   'Price': '290,000 ',
#   'model': 'טסלה מודל 3',
#   'Cre_date': '31/01/2022',
#   'Repub_date': '31/01/2022'},
#  {'שנה': 2021,
#   'יד': 1,
#   'ת. הילוכים': 'רובוטית',
#   'נפח': 1500,
#   'סוג מנוע': 'חשמלי',
#   'ק"מ': '6,183',
#   'צבע': 'סגול מטאלי',
#   'בעלות קודמת': 'אחר',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'חיפה וחוף הכרמל',
#   'עיר': 'חיפה',
#   'Pic_num': 9,
#   'Price': '340,000 ',
#   'model': 'טסלה מודל X',
#   'Cre_date': '20/09/2021',
#   'Repub_date': '26/09/2021'},
#  {'שנה': 2021,
#   'יד': 1,
#   'ת. הילוכים': 'רובוטית',
#   'נפח': 1500,
#   'סוג מנוע': 'חשמלי',
#   'ק"מ': '98',
#   'צבע': 'לבן',
#   'בעלות קודמת': 'אחר',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'חיפה וחוף הכרמל',
#   'עיר': 'חיפה',
#   'Pic_num': 11,
#   'Price': '355,000 ',
#   'model': 'טסלה מודל X',
#   'Cre_date': '22/09/2021',
#   'Repub_date': '26/09/2021'},
#  {'שנה': 2022,
#   'יד': 1,
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': 800,
#   'סוג מנוע': 'חשמלי',
#   'צבע': 'לבן',
#   'בעלות קודמת': 'ליסינג',
#   'בעלות נוכחית': 'ליסינג',
#   'אזור': 'אשדוד - אשקלון',
#   'עיר': 'אשקלון',
#   'Pic_num': 10,
#   'Price': '206,000 ',
#   'model': 'טסלה מודל 3',
#   'Cre_date': '09/02/2023',
#   'Repub_date': '10/04/2023'},
#  {'שנה': 2022,
#   'יד': 1,
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': 2000,
#   'סוג מנוע': 'חשמלי',
#   'ק"מ': '3,500',
#   'טסט עד': '12/2024',
#   'צבע': 'לבן פנינה',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'ראשל"צ והסביבה',
#   'עיר': 'ראשון לציון',
#   'Pic_num': 0,
#   'Price': '230,000 ',
#   'model': 'טסלה מודל 3',
#   'Cre_date': '02/01/2023',
#   'Repub_date': '02/01/2023'},
#  {'שנה': 2021,
#   'יד': 1,
#   'ת. הילוכים': 'טיפטרוניק',
#   'נפח': 2000,
#   'סוג מנוע': 'חשמלי',
#   'ק"מ': '10,000',
#   'אזור': 'תל אביב',
#   'עיר': 'תל אביב יפו',
#   'Pic_num': 0,
#   'Price': 'חיפה רמת ויזניץ',
#   'model': 'טסלה מודל 3',
#   'Cre_date': '28/07/2022',
#   'Repub_date': '28/07/2022'},
#  {'שנה': 2022,
#   'יד': 1,
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': 6000,
#   'סוג מנוע': 'חשמלי',
#   'צבע': 'לבן',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'תל אביב',
#   'עיר': 'תל אביב יפו',
#   'Pic_num': 0,
#   'Price': '10,000 ',
#   'model': 'טסלה מודל 3',
#   'Cre_date': '23/03/2022',
#   'Repub_date': '23/03/2022'}]

# %%
df = pd.DataFrame(tesla)
df = df.rename(columns={'שנה': 'Year', 'יד': 'Hand','ת. הילוכים': 'Gear', 'נפח': 'Engine_capacity','סוג מנוע': 'Engine_type', 'ק"מ': 'Km','טסט עד': 'Test', 'צבע': 'Color','עיר': 'City', 'אזור': 'Area','בעלות נוכחית':'Prev_ownership','בעלות קודמת':'Curr_ownership'})
df['manufacturer'] = 'Tesla'
df['Test']
# Out:
# 0     06/2025
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26    12/2024
# 27        NaN
# 28        NaN
# Name: Test, dtype: object

# %%
df['Cre_date'] = pd.to_datetime(df['Cre_date'],dayfirst=True)
df['Test'] = pd.to_datetime(df['Test'],dayfirst=True)
df['Gear'] = pd.Categorical(df['Gear'])
df['Km'] = pd.to_numeric(df['Km'], errors='coerce').fillna(0).astype(int)
df['Engine_type'] = pd.Categorical(df['Engine_type'])
df['Curr_ownership'] = pd.Categorical(df['Curr_ownership'])
df['Prev_ownership'] = pd.Categorical(df['Prev_ownership'])
df['Area'] = df['Area'].astype(str)
df['Price'] = pd.to_numeric(df['Price'], errors='coerce').fillna(0).astype(float)
df['Repub_date'] = pd.to_datetime(df['Repub_date'],dayfirst=True)
df['manufacturer'] = 'Tesla'
ordered_list = ['manufacturer','Year', 'Hand', 'Gear', 'Engine_capacity', 'Engine_type', 'Km', 'Test', 'Color',
     'Curr_ownership', 'Prev_ownership', 'Area', 'City', 'Pic_num', 'Price', 'model',
     'Cre_date', 'Repub_date']


df = df.reindex(columns=ordered_list)

# %%
df.to_csv('tesla.csv', index = False)

# %%
df
# Out:
#    manufacturer  Year  Hand       Gear  Engine_capacity Engine_type  Km  \
# 0         Tesla  2021     1   אוטומטית           6000.0       חשמלי   0
# 1         Tesla  2022     1   אוטומטית            800.0       חשמלי   0
# 2         Tesla  2018     2    רובוטית           1000.0       חשמלי   0
# 3         Tesla  2021     2   אוטומטית           4900.0       חשמלי   0
# 4         Tesla  2023     2   אוטומטית           6000.0       חשמלי   0
# 5         Tesla  2023     1   אוטומטית           3000.0       חשמלי   0
# 6         Tesla  2021     1   אוטומטית           5000.0       חשמלי   0
# 7         Tesla  2022     2   אוטומטית           6000.0       חשמלי   0
# 8         Tesla  2022     1   אוטומטית           6000.0       חשמלי   0
# 9         Tesla  2021     1   אוטומטית              NaN       חשמלי   0
# 10        Tesla  2022     1   אוטומטית           1234.0       חשמלי   0
# 11        Tesla  2021     1   אוטומטית              NaN       חשמלי   0
# 12        Tesla  2021     1   אוטומטית              5.0       חשמלי   0
# 13        Tesla  2021     1   אוטומטית            325.0       חשמלי   0
# 14        Tesla  2021     1   אוטומטית              NaN       חשמלי   0
# 15        Tesla  2021     1   אוטומטית              NaN       חשמלי   0
# 16        Tesla  2021     1   אוטומטית              NaN       חשמלי   0
# 17        Tesla  2021     1   אוטומטית          50000.0       חשמלי   0
# 18        Tesla  2021     1   אוטומטית              NaN       חשמלי   0
# 19        Tesla  2021     1   אוטומטית           3600.0       חשמלי   0
# 20        Tesla  2022     1   אוטומטית           4500.0       חשמלי   0
# 21        Tesla  2022     1   אוטומטית           4500.0       חשמלי   0
# 22        Tesla  2022     1   אוטומטית           4500.0       חשמלי   0
# 23        Tesla  2021     1    רובוטית           1500.0       חשמלי   0
# 24        Tesla  2021     1    רובוטית           1500.0       חשמלי  98
# 25        Tesla  2022     1   אוטומטית            800.0       חשמלי   0
# 26        Tesla  2022     1   אוטומטית           2000.0       חשמלי   0
# 27        Tesla  2021     1  טיפטרוניק           2000.0       חשמלי   0
# 28        Tesla  2022     1   אוטומטית           6000.0       חשמלי   0
#
#          Test       Color Curr_ownership Prev_ownership                 Area  \
# 0  2025-06-01        שחור          פרטית          פרטית       ראשל"צ והסביבה
# 1         NaT         לבן          פרטית          פרטית      רעננה - כפר סבא
# 2         NaT        שחור          פרטית          פרטית     רמת גן - גבעתיים
# 3         NaT   לבן פנינה          פרטית          פרטית    נס ציונה - רחובות
# 4         NaT   לבן פנינה          פרטית          פרטית      ירושלים והסביבה
# 5         NaT    לבן שנהב           חברה           חברה  חדרה וישובי עמק חפר
# 6         NaT   לבן פנינה          פרטית          פרטית           עמק יזרעאל
# 7         NaT        כחול          פרטית          פרטית     רמת גן - גבעתיים
# 8         NaT   לבן פנינה          פרטית          פרטית      ירושלים והסביבה
# 9         NaT         NaN            NaN            NaN      באר שבע והסביבה
# 10        NaT         NaN            NaN            NaN      מודיעין והסביבה
# 11        NaT         NaN            NaN            NaN       אשדוד - אשקלון
# 12        NaT         NaN            NaN            NaN                  nan
# 13        NaT         NaN            NaN            NaN          אילת והערבה
# 14        NaT         NaN            NaN            NaN    הוד השרון והסביבה
# 15        NaT         NaN            NaN            NaN      מודיעין והסביבה
# 16        NaT         NaN            NaN            NaN      רעננה - כפר סבא
# 17        NaT         NaN            NaN            NaN      רעננה - כפר סבא
# 18        NaT         NaN            NaN            NaN        חולון - בת ים
# 19        NaT   לבן מטאלי          פרטית          פרטית      באר שבע והסביבה
# 20        NaT   לבן פנינה            אחר            אחר      ירושלים והסביבה
# 21        NaT   לבן פנינה            אחר            אחר      ירושלים והסביבה
# 22        NaT   לבן פנינה            אחר            אחר      ירושלים והסביבה
# 23        NaT  סגול מטאלי            אחר          פרטית      חיפה וחוף הכרמל
# 24        NaT         לבן            אחר          פרטית      חיפה וחוף הכרמל
# 25        NaT         לבן         ליסינג         ליסינג       אשדוד - אשקלון
# 26 2024-12-01   לבן פנינה          פרטית          פרטית       ראשל"צ והסביבה
# 27        NaT         NaN            NaN            NaN              תל אביב
# 28        NaT         לבן          פרטית          פרטית              תל אביב
#
#                   City  Pic_num  Price        model   Cre_date Repub_date
# 0             באר יעקב       10    0.0  טסלה מודל 3 2024-05-20 2024-05-26
# 1              כפר סבא       10    0.0  טסלה מודל 3 2024-01-21 2024-05-22
# 2              בני ברק        5    0.0  טסלה מודל S 2024-03-22 2024-03-22
# 3               רחובות        4    0.0  טסלה מודל 3 2023-09-02 2023-09-02
# 4              ירושלים        1    0.0  טסלה מודל 3 2023-08-16 2023-08-16
# 5                 חדרה        8    0.0  טסלה מודל X 2023-06-16 2023-06-16
# 6           קרית טבעון        2    0.0  טסלה מודל 3 2023-04-10 2023-04-14
# 7               רמת גן        3    0.0  טסלה מודל 3 2023-02-08 2023-02-14
# 8                 שורש        4    0.0  טסלה מודל S 2023-01-18 2023-01-18
# 9              באר שבע        1    0.0  טסלה מודל 3 2022-10-17 2022-10-17
# 10  מודיעין מכבים רעות        1    0.0  טסלה מודל 3 2022-10-13 2022-10-13
# 11            תלמי יפה        1    0.0  טסלה מודל 3 2022-10-13 2022-10-13
# 12              Ofaqim        1    0.0  טסלה מודל 3 2022-10-03 2022-10-03
# 13                אילת        1    0.0  טסלה מודל 3 2022-10-03 2022-10-03
# 14           הוד השרון        1    0.0  טסלה מודל 3 2022-09-06 2022-09-06
# 15  מודיעין מכבים רעות        1    0.0  טסלה מודל 3 2022-08-31 2022-08-31
# 16             כפר סבא        1    0.0  טסלה מודל 3 2022-08-29 2022-08-29
# 17             כפר סבא        1    0.0  טסלה מודל 3 2022-07-08 2022-07-08
# 18               בת ים        1    0.0  טסלה מודל 3 2022-04-20 2022-04-20
# 19              דימונה        1    0.0  טסלה מודל 3 2022-02-07 2022-02-07
# 20             ירושלים        1    0.0  טסלה מודל 3 2022-01-31 2022-01-31
# 21             ירושלים        1    0.0  טסלה מודל 3 2022-01-31 2022-01-31
# 22             ירושלים        1    0.0  טסלה מודל 3 2022-01-31 2022-01-31
# 23                חיפה        9    0.0  טסלה מודל X 2021-09-20 2021-09-26
# 24                חיפה       11    0.0  טסלה מודל X 2021-09-22 2021-09-26
# 25              אשקלון       10    0.0  טסלה מודל 3 2023-02-09 2023-04-10
# 26         ראשון לציון        0    0.0  טסלה מודל 3 2023-01-02 2023-01-02
# 27         תל אביב יפו        0    0.0  טסלה מודל 3 2022-07-28 2022-07-28
# 28         תל אביב יפו        0    0.0  טסלה מודל 3 2022-03-23 2022-03-23
